# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import emoji
import re

# import seaborn as sns
# import matplotlib.pyplot as plt
# import nltk

# %% [markdown]
# DATA KOTOR

# %%
df = pd.read_csv("/content/drive/MyDrive/SKRIPSI/New/a_label_dep.csv", encoding='latin1')
df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.860000e+18  Fri Nov 15 23:36:57 +0000 2024               0
# 1            1.860000e+18  Fri Nov 15 23:36:39 +0000 2024               0
# 2            1.890000e+18  Fri Jan 31 23:51:35 +0000 2025               1
# 3            1.890000e+18  Fri Jan 31 23:30:44 +0000 2025               0
# 4            1.890000e+18  Fri Jan 31 23:27:21 +0000 2025               4
# ...                   ...                             ...             ...
# 4995         1.860000e+18  Wed Oct 23 15:28:50 +0000 2024               0
# 4996         1.860000e+18  Wed Oct 23 15:19:03 +0000 2024               0
# 4997         1.860000e+18  Wed Oct 23 15:15:21 +0000 2024               0
# 4998         1.860000e+18  Wed Oct 23 15:15:05 +0000 2024               0
# 4999         1.860000e+18  Wed Oct 23 15:14:54 +0000 2024               0
#
#         label                                          full_text  \
# ...

# %%
# Ambil 5 data paling awal dan 5 data terakhir
df_first_5 = df.head(5)  # Ambil 5 data pertama
df_last_5 = df.tail(5)   # Ambil 5 data terakhir

# Gabungkan hasilnya untuk menampilkan
df_combined = pd.concat([df_first_5, df_last_5])

# Tampilkan hasilnya
print("5 Data Paling Awal dan 5 Data Terakhir:")
print(df_combined)

# Cek bentuk DataFrame setelah slicing
print("Shape setelah slicing:", df_combined.shape)
# Out:
# 5 Data Paling Awal dan 5 Data Terakhir:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.860000e+18  Fri Nov 15 23:36:57 +0000 2024               0
# 1            1.860000e+18  Fri Nov 15 23:36:39 +0000 2024               0
# 2            1.890000e+18  Fri Jan 31 23:51:35 +0000 2025               1
# 3            1.890000e+18  Fri Jan 31 23:30:44 +0000 2025               0
# 4            1.890000e+18  Fri Jan 31 23:27:21 +0000 2025               4
# 4995         1.860000e+18  Wed Oct 23 15:28:50 +0000 2024               0
# 4996         1.860000e+18  Wed Oct 23 15:19:03 +0000 2024               0
# 4997         1.860000e+18  Wed Oct 23 15:15:21 +0000 2024               0
# 4998         1.860000e+18  Wed Oct 23 15:15:05 +0000 2024               0
# 4999         1.860000e+18  Wed Oct 23 15:14:54 +0000 2024               0
#
#         label                                          full_text  \
# ...

# %%
df_combined
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0            1.860000e+18  Fri Nov 15 23:36:57 +0000 2024               0
# 1            1.860000e+18  Fri Nov 15 23:36:39 +0000 2024               0
# 2            1.890000e+18  Fri Jan 31 23:51:35 +0000 2025               1
# 3            1.890000e+18  Fri Jan 31 23:30:44 +0000 2025               0
# 4            1.890000e+18  Fri Jan 31 23:27:21 +0000 2025               4
# 4995         1.860000e+18  Wed Oct 23 15:28:50 +0000 2024               0
# 4996         1.860000e+18  Wed Oct 23 15:19:03 +0000 2024               0
# 4997         1.860000e+18  Wed Oct 23 15:15:21 +0000 2024               0
# 4998         1.860000e+18  Wed Oct 23 15:15:05 +0000 2024               0
# 4999         1.860000e+18  Wed Oct 23 15:14:54 +0000 2024               0
#
#         label                                          full_text  \
# 0     depresi                   aku sedih pdhl lg pgn di support
# ...

# %% [markdown]
# HAPUS ATRIBUT

# %%
columns_to_drop = ['conversation_id_str','image_url','favorite_count','id_str',
                   'location','image_url','in_reply_to_screen_name','lang',
                   'quote_count','reply_count','retweet_count','tweet_url',
                   'user_id_str','created_at','username']
df = df_combined.drop(columns=columns_to_drop, errors='ignore')

# %%
df.shape
# Out:
# (10, 2)

# %%
df
# Out:
#         label                                          full_text
# 0     depresi                   aku sedih pdhl lg pgn di support
# 1      normal  @muh_basra Keknya beban depresi pada cash for ...
# 2     depresi  gue udah di titik cape banget nutup nutupin im...
# 3     depresi  Kadang pengen gw ledakin tapi takut ada yg nyi...
# 4      normal  Rasa bersalah juga kalau jumpa mashayikh tak c...
# 4995  depresi  Hari demi hari makin di bikin takut buat ngela...
# 4996  depresi  nyerah aja kali ya beneran capek sm kehidupan ...
# 4997   normal  @diddekarisma Udah nyerah sama hidup tuh makan...
# 4998  depresi  udah di tahap nyerah sm diri sendiri nyoba bua...
# 4999   normal  @iteramfs Gk usah kkn nder nanti rame2 bilang ...

# %% [markdown]
# CASE FOLDING

# %%
df['full_text'] = df['full_text'].str.lower()
df
# Out:
#         label                                          full_text
# 0     depresi                   aku sedih pdhl lg pgn di support
# 1      normal  @muh_basra keknya beban depresi pada cash for ...
# 2     depresi  gue udah di titik cape banget nutup nutupin im...
# 3     depresi  kadang pengen gw ledakin tapi takut ada yg nyi...
# 4      normal  rasa bersalah juga kalau jumpa mashayikh tak c...
# 4995  depresi  hari demi hari makin di bikin takut buat ngela...
# 4996  depresi  nyerah aja kali ya beneran capek sm kehidupan ...
# 4997   normal  @diddekarisma udah nyerah sama hidup tuh makan...
# 4998  depresi  udah di tahap nyerah sm diri sendiri nyoba bua...
# 4999   normal  @iteramfs gk usah kkn nder nanti rame2 bilang ...

# %% [markdown]
# CLEANING

# %%
df = df.drop_duplicates(subset=['full_text'])
df.duplicated().sum()

# %%
def clean_text(text):
    # Menghapus mention
    text = re.sub(r'@[A-Za-z0-9_]+', '', text)
    # Menghapus hashtag
    text = re.sub(r'#', '', text)
    # Menghapus link
    text = re.sub(r'http[s]?://\S+', '', text)
    # Menghapus karakter non-alfanumerik
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)
    # Menghapus spasi berlebihan
    text = re.sub(r'\s+', ' ', text).strip()
    # mengubah emoji menjadi text
    text = emoji.demojize(text)
    # mengubah tanda baca berulang menjadi tunggal
    text = re.sub(r'([^\w\s])\1+', r'\1', text)

    return text

df['full_text'] = df['full_text'].apply(clean_text)
df
# Out:
#         label                                          full_text
# 0     depresi                   aku sedih pdhl lg pgn di support
# 1      normal  keknya beban depresi pada cash for healing ga ...
# 2     depresi  gue udah di titik cape banget nutup nutupin im...
# 3     depresi  kadang pengen gw ledakin tapi takut ada yg nyi...
# 4      normal  rasa bersalah juga kalau jumpa mashayikh tak c...
# 4995  depresi  hari demi hari makin di bikin takut buat ngela...
# 4996  depresi  nyerah aja kali ya beneran capek sm kehidupan ...
# 4997   normal  udah nyerah sama hidup tuh makanya nyemplungin...
# 4998  depresi  udah di tahap nyerah sm diri sendiri nyoba bua...
# 4999   normal  gk usah kkn nder nanti rame2 bilang yg salah p...

# %%
df.to_csv('/content/drive/MyDrive/SKRIPSI/New/10_prepo_dep.csv', index=False)

# %% [markdown]
# NORMALIZATION

# %%
import csv
import string
import pandas as pd
import re

# %%
import requests

url = "https://github.com/nasalsabila/kamus-alay/blob/master/colloquial-indonesian-lexicon.csv"

response = requests.get(url)
if response.status_code == 200:
    print("File berhasil diakses!")
    print(response.text[:500])  # Cek sebagian isi file
else:
    print("Gagal mengakses file. Error:", response.status_code)
# Out:
# File berhasil diakses!
#
#
#
#
#
#
# <!DOCTYPE html>
# <html
#   lang="en"
#
#   data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"
#   data-a11y-animated-images="system" data-a11y-link-underlines="true"
#
#   >
#
#
#
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.gi

# %%
# URL file CSV di GitHub (RAW)
url = "https://raw.githubusercontent.com/nasalsabila/kamus-alay/master/colloquial-indonesian-lexicon.csv"

# Membaca CSV dengan delimiter koma (",") atau sesuaikan dengan file
slang_df = pd.read_csv(url, delimiter=",", header=None)

# Ambil kolom pertama sebagai daftar slang-formal
slang_list = slang_df.iloc[:, 0].tolist()

# Cek 10 kata pertama dari daftar stopword
print(slang_list[:10])
# Out:
# ['slang', 'woww', 'aminn', 'met', 'netaas', 'keberpa', 'eeeehhhh', 'kata2nyaaa', 'hallo', 'kaka']

# %%
try:
    #Baca CSV dengan delimiter otomatis
    slang_df = pd.read_csv(url, sep=None, engine='python')

    #Cek apakah CSV memiliki 2 kolom
    if slang_df.shape[1] < 2:
        raise ValueError("File CSV tidak memiliki dua kolom untuk normalisasi!")

    #Buat dictionary slang jadi formal
    norm_dict = dict(zip(slang_df.iloc[:, 0], slang_df.iloc[:, 1]))

    #Fungsi normalisasi menggunakan regex
    def normalisasi(str_text):
        words = str_text.split()  # Pecah kalimat jadi list kata
        words = [norm_dict.get(word, word) for word in words]
        return " ".join(words)  # Gabungkan kembali jadi kalimat

    #Baca file dataset lokal
    file_lokal = "/content/drive/MyDrive/SKRIPSI/New/10_prepo_dep.csv"
    df = pd.read_csv(file_lokal)

    #Pastikan kolom 'full_text' ada
    if 'full_text' not in df.columns:
        raise ValueError("Kolom 'full_text' tidak ditemukan dalam file lokal!")

    #Terapkan normalisasi
    df['full_text'] = df['full_text'].astype(str).apply(normalisasi)

except Exception as e:
    print(f"Terjadi error: {e}")

# %%
df
# Out:
#      label                                          full_text
# 0  depresi           aku sedih padahal lagi pengin di support
# 1   normal  kayaknya beban depresi pada cash for healing e...
# 2  depresi  gue sudah di titik capek banget nutup menutupi...
# 3  depresi  kadang pengin gue ledakin tapi takut ada yang ...
# 4   normal  rasa bersalah juga kalau jumpa mashayikh tak c...
# 5  depresi  hari demi hari makin di bikin takut buat ngela...
# 6  depresi  nyerah saja kali ya benaran capek sama kehidup...
# 7   normal  sudah nyerah sama hidup tuh makanya nyemplungi...
# 8  depresi  sudah di tahap nyerah sama diri sendiri mencob...
# 9   normal  enggak usah kkn nder nanti rame-rame bilang ya...

# %% [markdown]
# STOPWORD REMOVAL

# %%
# !pip install Sastrawi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 12.3 MB/s eta 0:00:00
# ...

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import (
    StopWordRemoverFactory, StopWordRemover, ArrayDictionary
)

# Stopword tambahan
more_stopword = ['tuh','lah','kok','sok','cs','sih','loh','nih']

# Buat daftar stopword menggunakan Sastrawi dan tambahkan stopword tambahan
stopwords = StopWordRemoverFactory().get_stop_words()
stopwords.extend(more_stopword)

# Inisialisasi StopWordRemover dengan daftar stopword yang diperbarui
new_array = ArrayDictionary(stopwords)
stopwords_remover = StopWordRemover(new_array)

# Fungsi untuk menghapus stopword
def remove_stopwords(text):
    return stopwords_remover.remove(text)

df['full_text'] = df['full_text'].apply(remove_stopwords)
df
# Out:
#      label                                          full_text
# 0  depresi                   aku sedih padahal pengin support
# 1   normal  kayaknya beban depresi cash for healing enggak...
# 2  depresi  gue titik capek banget nutup menutupi image ke...
# 3  depresi  kadang pengin gue ledakin takut yang nyiksa di...
# 4   normal  rasa bersalah kalau jumpa mashayikh tak cuba k...
# 5  depresi  hari hari makin bikin takut buat ngelanjutin h...
# 6  depresi  nyerah kali benaran capek sama kehidupan capek...
# 7   normal  nyerah sama hidup makanya nyemplungin diri minyak
# 8  depresi  di tahap nyerah sama diri sendiri mencoba buat...
# 9   normal  enggak usah kkn nder rame-rame bilang salah pa...

# %% [markdown]
# CONVERT VALUE

# %%
df['label'] = df['label'].astype(str).str.strip().str.lower()
print(df['label'].unique())  # pastikan label hanya "depresi" dan "normal"
# Out:
# ['depresi' 'normal']

# %%
df['label'] = df['label'].map({"depresi": 1, "normal": 0})

# %%
print(df['label'].isnull().sum())
# Out:
# 0

# %%
df
# Out:
#    label                                          full_text
# 0      1                   aku sedih padahal pengin support
# 1      0  kayaknya beban depresi cash for healing enggak...
# 2      1  gue titik capek banget nutup menutupi image ke...
# 3      1  kadang pengin gue ledakin takut yang nyiksa di...
# 4      0  rasa bersalah kalau jumpa mashayikh tak cuba k...
# 5      1  hari hari makin bikin takut buat ngelanjutin h...
# 6      1  nyerah kali benaran capek sama kehidupan capek...
# 7      0  nyerah sama hidup makanya nyemplungin diri minyak
# 8      1  di tahap nyerah sama diri sendiri mencoba buat...
# 9      0  enggak usah kkn nder rame-rame bilang salah pa...
